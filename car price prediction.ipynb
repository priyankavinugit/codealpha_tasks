# %% [markdown]
# # Importing Libraries

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set()
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load the dataset

# %%
df=pd.read_csv("C:/Users/VinoSekar-VP/Desktop/priya data analyst/Internship/Code Alpha/Dataset/car data.csv")
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner
# 0         Dealer       Manual      0
# 1         Dealer       Manual      0
# ...

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Selling_type Transmission  Owner
# 0       Dealer       Manual      0
# 1       Dealer       Manual      0
# 2       Dealer       Manual      0
# 3       Dealer       Manual      0
# 4       Dealer       Manual      0

# %%
df.tail()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 296     city  2016           9.50           11.6       33988    Diesel
# 297     brio  2015           4.00            5.9       60000    Petrol
# 298     city  2009           3.35           11.0       87934    Petrol
# 299     city  2017          11.50           12.5        9000    Diesel
# 300     brio  2016           5.30            5.9        5464    Petrol
#
#     Selling_type Transmission  Owner
# 296       Dealer       Manual      0
# 297       Dealer       Manual      0
# 298       Dealer       Manual      0
# 299       Dealer       Manual      0
# 300       Dealer       Manual      0

# %%
df.shape
# Out:
# (301, 9)

# %% [markdown]
# # Information about dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Driven_kms     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Selling_type   301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Driven_kms       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.642584   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Driven_kms       0
# Fuel_Type        0
# Selling_type     0
# Transmission     0
# Owner            0
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.duplicated().sum()
# Out:
# 2

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (299, 9)

# %%
df.nunique()
# Out:
# Car_Name          98
# Year              16
# Selling_Price    156
# Present_Price    148
# Driven_kms       206
# Fuel_Type          3
# Selling_type       2
# Transmission       2
# Owner              3
# dtype: int64

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Driven_kms',
#        'Fuel_Type', 'Selling_type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
numerical_columns=df.select_dtypes(include=["number"])
numerical_columns
# Out:
#      Year  Selling_Price  Present_Price  Driven_kms  Owner
# 0    2014           3.35           5.59       27000      0
# 1    2013           4.75           9.54       43000      0
# 2    2017           7.25           9.85        6900      0
# 3    2011           2.85           4.15        5200      0
# 4    2014           4.60           6.87       42450      0
# ..    ...            ...            ...         ...    ...
# 296  2016           9.50          11.60       33988      0
# 297  2015           4.00           5.90       60000      0
# 298  2009           3.35          11.00       87934      0
# 299  2017          11.50          12.50        9000      0
# 300  2016           5.30           5.90        5464      0
#
# [299 rows x 5 columns]

# %%
categorical_columns=df.select_dtypes(include=["object"])
categorical_columns
# Out:
#     Car_Name Fuel_Type Selling_type Transmission
# 0       ritz    Petrol       Dealer       Manual
# 1        sx4    Diesel       Dealer       Manual
# 2       ciaz    Petrol       Dealer       Manual
# 3    wagon r    Petrol       Dealer       Manual
# 4      swift    Diesel       Dealer       Manual
# ..       ...       ...          ...          ...
# 296     city    Diesel       Dealer       Manual
# 297     brio    Petrol       Dealer       Manual
# 298     city    Petrol       Dealer       Manual
# 299     city    Diesel       Dealer       Manual
# 300     brio    Petrol       Dealer       Manual
#
# [299 rows x 4 columns]

# %% [markdown]
# # Data Visualization and EDA

# %%
plt.figure(figsize=(10,8))
sns.boxplot(data=df)
plt.title("Outliers in data")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(df['Selling_Price'],palette='viridis')
plt.title("Selling Price")
plt.show()

# %%
#numerical_df=df[numerical_columns]
correlation_matrix=numerical_columns.corr()
plt.figure(figsize=(10,8))
sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm',fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %%
numerical_features=['Year','Driven_kms','Selling_Price','Present_Price']
for feature in numerical_features:
    plt.figure(figsize=(10,8))
    sns.displot(data=df,x=feature,kde=True)
    plt.title(f'Distribution of{feature}')
    plt.show()

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data=df,x='Driven_kms',y='Selling_Price')
plt.title("Relationship between Selling Price and Driven kms")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data=df,x='Present_Price',y='Selling_Price')
plt.title("Relationship between Selling Price and Present Price")
plt.show()

# %%
color=sns.color_palette("Set2")
categorical_features=['Fuel_Type','Selling_type','Transmission']
for feature in categorical_features:
    plt.figure(figsize=(10,8))
    sns.countplot(x=feature,data=df,palette=color)
    plt.title(f'Frequency of {feature}',fontsize=18,color='darkblue',fontweight='bold')
    plt.xlabel(f'{feature}',fontsize=16,color='navy')
    plt.ylabel('Frequency',fontsize=16,color='navy')
    plt.grid(axis='y',linestyle='--',alpha=0.8)
    plt.show()

# %%
n=20
top_car_models=df['Car_Name'].value_counts().head(n)
plt.figure(figsize=(10,6))
sns.barplot(x=top_car_models.values,y=top_car_models.index,hue=top_car_models)
plt.title(f'Top {n} Car Models by Frequency')
plt.xlabel('Frequency')
plt.ylabel('Car Model')
plt.tight_layout()
plt.show()

# %%
#Calculate Average Prices of Car
avg_prices_car=df.groupby('Car_Name')['Selling_Price'].mean().sort_values(ascending=False)
n=20
top_car_models=avg_prices_car.head(n)
plt.figure(figsize=(10,8))
sns.barplot(x=top_car_models.values,y=top_car_models.index,palette='viridis')
plt.title(f'Top {n} Car Models Average Price')
plt.xlabel('Average Price')
plt.ylabel('Car Model')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Data Cleaning and Transformation

# %%
print(categorical_features)
# Out:
# ['Fuel_Type', 'Selling_type', 'Transmission']

# %%
print(df['Fuel_Type'].value_counts())
# Out:
# Fuel_Type
# Petrol    239
# Diesel     58
# CNG         2
# Name: count, dtype: int64

# %%
print(df['Selling_type'].value_counts())
# Out:
# Selling_type
# Dealer        193
# Individual    106
# Name: count, dtype: int64

# %%
print(df['Transmission'].value_counts())
# Out:
# Transmission
# Manual       260
# Automatic     39
# Name: count, dtype: int64

# %% [markdown]
# # Encode Categorical Features

# %%
df.replace({'Fuel_Type':{'Petrol':0,'Diesel':1,'CNG':2}},inplace=True)
df.replace({'Selling_type':{'Dealer':0,'Individual':1}},inplace=True)
df.replace({'Transmission':{'Manual':0,'Automatic':1}},inplace=True)

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms  Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000          0
# 1      sx4  2013           4.75           9.54       43000          1
# 2     ciaz  2017           7.25           9.85        6900          0
# 3  wagon r  2011           2.85           4.15        5200          0
# 4    swift  2014           4.60           6.87       42450          1
#
#    Selling_type  Transmission  Owner
# 0             0             0      0
# 1             0             0      0
# 2             0             0      0
# 3             0             0      0
# 4             0             0      0

# %%
df.tail()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms  Fuel_Type  \
# 296     city  2016           9.50           11.6       33988          1
# 297     brio  2015           4.00            5.9       60000          0
# 298     city  2009           3.35           11.0       87934          0
# 299     city  2017          11.50           12.5        9000          1
# 300     brio  2016           5.30            5.9        5464          0
#
#      Selling_type  Transmission  Owner
# 296             0             0      0
# 297             0             0      0
# 298             0             0      0
# 299             0             0      0
# 300             0             0      0

# %%
df.shape
# Out:
# (299, 9)

# %% [markdown]
# # Prediction

# %%
#Define target variable
x=df.drop(['Car_Name','Selling_Price'],axis=1)
y=df['Selling_Price']

# %%
x
# Out:
#      Year  Present_Price  Driven_kms  Fuel_Type  Selling_type  Transmission  \
# 0    2014           5.59       27000          0             0             0
# 1    2013           9.54       43000          1             0             0
# 2    2017           9.85        6900          0             0             0
# 3    2011           4.15        5200          0             0             0
# 4    2014           6.87       42450          1             0             0
# ..    ...            ...         ...        ...           ...           ...
# 296  2016          11.60       33988          1             0             0
# 297  2015           5.90       60000          0             0             0
# 298  2009          11.00       87934          0             0             0
# 299  2017          12.50        9000          1             0             0
# 300  2016           5.90        5464          0             0             0
#
#      Owner
# 0        0
# 1        0
# 2        0
# ...

# %%
y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 299, dtype: float64

# %% [markdown]
# # Linear Regression Model

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score,accuracy_score,confusion_matrix,classification_report

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=51)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Model Evaluation

# %%
y_pred=model.predict(x_test)
mse=mean_squared_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
print('Mean Squared error:',mse)
print('R-Squared:',r2)
# Out:
# Mean Squared error: 3.01100915883385
# R-Squared: 0.8819553928868337

# %% [markdown]
# # Predicting the model

# %%
new_car=[[2024,25000,0,1,1,0,0]]
#Example Car data
predicted_price=model.predict(new_car)
print('Predicted Selling Price:',predicted_price[0])
# Out:
# Predicted Selling Price: 10796.644426986813
